# %%
import os

# Creamos las carpetas para no mezclar los CSV con los ZIPs pesados
os.makedirs("Anotaciones", exist_ok=True)
os.makedirs("Imagenes_Originales", exist_ok=True)
print("Carpetas creadas con éxito.")
# Out:
# Carpetas creadas con éxito.

# %%
# Nos movemos a la carpeta de anotaciones
# %cd Anotaciones

# Ejecutamos la herramienta de Zenodo para descargar el ID 14673658
# !zenodo_get 14673658

# Volvemos a la carpeta principal LUNA25
# %cd ..
# Out:
# /home/unix/LUNA25/Anotaciones
# INFO: Output directory: /home/unix/LUNA25/Anotaciones
# INFO: Title: The LUNA25 Challenge: Public Training and Development set - Annotation Data
# INFO: Total size: 860.9 kB
# INFO: Number of files: 1
# SUCCESS: All specified files have been processed.
# /home/unix/LUNA25

# %%
# Nos movemos a la carpeta de imágenes
# %cd Imagenes_Originales

# Iniciamos la descarga masiva del ID 14223624
# Al ejecutar esta celda, verás la barra de progreso de los 46 archivos
# !zenodo_get 14223624

# Volvemos a la carpeta principal al terminar
# %cd ..
# Out:
# /home/unix/LUNA25/Imagenes_Originales
# INFO: Output directory: /home/unix/LUNA25/Imagenes_Originales
# INFO: Title: The LUNA25 Challenge: Public Training and Development set - Imaging Data
# INFO: Total size: 221.1 GB
# INFO: Number of files: 48
# Files:   0%|                                           | 0/48 [00:00<?, ?file/s]
